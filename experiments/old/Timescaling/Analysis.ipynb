# %%
from phimal_utilities.analysis import Results
import matplotlib.pyplot as plt
import numpy as np
# %config InlineBackend.figure_format='retina'

# %%
# load in data; just give path of tensorboard files
data = Results('runs/dt_differentiable/')

# %%
# Quickly plot all the losses
data.plot_losses()

# %%
# Or the coefficients
data.plot_coeffs()

# %%
# select the coefficients keys:
plt.plot(np.abs(data.df[data.keys['coeffs']]))
plt.plot(np.abs(data.df[data.keys['coeffs'][3]]), lw=3)
plt.plot(np.abs(data.df[data.keys['coeffs'][5]]), lw=3)

# %%
plt.semilogy(data.df[data.keys['mse']])
plt.axhline(0.0413)
