# %%
# General imports
import numpy as np
import torch

import matplotlib.pyplot as plt

# DeepMoD stuff
from multitaskpinn import DeepMoD
from multitaskpinn.model.func_approx import NN
from multitaskpinn.model.library import Library1D
from multitaskpinn.model.constraint import LeastSquares
from multitaskpinn.model.sparse_estimators import Threshold
from multitaskpinn.training.sparsity_scheduler import TrainTestPeriodic
from experiment_code import train

from multitaskpinn.data import Dataset
from multitaskpinn.data.kdv import DoubleSoliton

from multitaskpinn.analysis import load_tensorboard

# %%
# Settings
if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'

# Settings for reproducibility
np.random.seed(42)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
x = np.linspace(-8, 5, 100)
t = np.linspace(0.0, 2.0, 40)
x_grid, t_grid = np.meshgrid(x, t, indexing='ij')

dataset = Dataset(DoubleSoliton, c=[5.0, 1.0], x0=[-5.0, -1.0])
X, y = dataset.create_dataset(x_grid.reshape(-1, 1), t_grid.reshape(-1, 1), n_samples=0, noise=0.2, random=True, normalize=False)
X, y = X.to(device), y.to(device)

# %%
plt.contourf(t_grid, x_grid, y.reshape(x_grid.shape).cpu())

# %%
# Running for multiple factors
factors = torch.logspace(-2, 2, 5)

for factor in factors:
    sparsity_scheduler = TrainTestPeriodic(periodicity=50, patience=200, delta=1e-4) # in terms of write iterations
    network = NN(2, [30, 30, 30, 30, 30], 1)
    library = Library1D(poly_order=2, diff_order=3) # Library function
    estimator = Threshold(0.1) # Sparse estimator 
    constraint = LeastSquares() # How to constrain
    model = DeepMoD(network, library, estimator, constraint).to(device) # Putting it all in the model
    optimizer = torch.optim.Adam(model.parameters(), betas=(0.99, 0.999), amsgrad=True, lr=1e-3) # Defining optimizer
    
    y_train = y * factor
    train(model, X, y_train, optimizer, sparsity_scheduler, exp_ID=f'data_scaling_factor_{factor:.1e}', split=0.8, write_iterations=50, max_iterations=1500, delta=1e-5, patience=200)
# Out:
#    500  MSE: 4.00e-05  Reg: 2.24e-07  L1: 2.00e+01 Algorithm converged. Writing model to disk.
#   1400  MSE: 1.87e-04  Reg: 3.39e-05  L1: 4.64e+00 Algorithm converged. Writing model to disk.
#   2450  MSE: 1.45e-02  Reg: 2.09e-04  L1: 3.61e+00 Algorithm converged. Writing model to disk.
#    800  MSE: 1.82e+01  Reg: 1.23e+00  L1: 1.37e+01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-17e27ce0b567> in <module>
#      12
#      13     y_train = y * factor
# ---> 14     train(model, X, y_train, optimizer, sparsity_scheduler, exp_ID=f'data_scaling_factor_{factor:.1e}', split=0.8, write_iterations=50, max_iterations=20000, delta=1e-5, patience=200)
#
# ~/Documents/MultiTaskPINN/paper/why_normal_bad/experiment_code.py in train(model, data, target, optimizer, sparsity_scheduler, lambda_reg, split, exp_ID, log_dir, max_iterations, write_iterations, **convergence_kwargs)
#      46     for iteration in torch.arange(0, max_iterations):
#      47         # ================== Training Model ============================
# ---> 48         prediction, time_derivs, thetas = model(data_train)
#      49
#      50         MSE = torch.mean((prediction - target_train)**2, dim=0)  # loss per output
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/Documents/MultiTaskPINN/src/multitaskpinn/model/deepmod.py in forward(self, input)
#     180         prediction, coordinates = self.func_approx(input)
#     181         time_derivs, thetas = self.library((prediction, coordinates))
# --> 182         self.constraint((time_derivs, thetas))
#     183         return prediction, time_derivs, thetas
#     184
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/Documents/MultiTaskPINN/src/multitaskpinn/model/deepmod.py in forward(self, input)
#      38
#      39         sparse_thetas = self.apply_mask(thetas)
# ---> 40         self.coeff_vectors = self.calculate_coeffs(sparse_thetas, time_derivs)
#      41
#      42
#
# ~/Documents/MultiTaskPINN/src/multitaskpinn/model/constraint.py in calculate_coeffs(self, sparse_thetas, time_derivs)
#      29         for theta, dt in zip(sparse_thetas, time_derivs):
#      30             Q, R = torch.qr(theta)  # solution of lst. sq. by QR decomp.
# ---> 31             opt_coeff.append(torch.inverse(R) @ Q.T @ dt)
#      32
#      33         # Putting them in the right spot
#
# KeyboardInterrupt:
