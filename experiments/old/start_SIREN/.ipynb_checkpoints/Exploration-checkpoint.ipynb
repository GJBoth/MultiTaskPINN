# %% [markdown]
# When should we start SIREN and how often should we perform sparsity selection? In this notebook we figure it out.

# %%
# General imports
import numpy as np
import torch

# DeepMoD Components
from multitaskpinn import DeepMoD
from multitaskpinn.model.func_approx import NN, Siren
from multitaskpinn.model.library import Library1D
from multitaskpinn.model.constraint import LeastSquares
from multitaskpinn.model.sparse_estimators import Threshold
from multitaskpinn.training import train
from multitaskpinn.training.sparsity_scheduler import Periodic

# Data
from phimal_utilities.data import Dataset
from phimal_utilities.data.kdv import DoubleSoliton

#Plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Cuda
if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'

print(f'running on {device}')
# Settings for reproducibility
np.random.seed(42)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %load_ext autoreload
# %autoreload 2
# Out:
# running on cuda

# %%
# Making data
x = np.linspace(-7, 5, 100)
t = np.linspace(0.0, 1.0, 50)

x_grid, t_grid = np.meshgrid(x, t, indexing='ij')
dataset = Dataset(DoubleSoliton, c=(5, 2), x0=(-3, -1))


X_full, y_full = dataset.create_dataset(x_grid.reshape(-1, 1), t_grid.reshape(-1, 1), n_samples=0, noise=0.0, normalize=False, random=False)

# %%
plt.contourf(t_grid, x_grid, y_full.reshape(x_grid.shape))
plt.xlabel('x')
plt.ylabel('t')
# Out:
# Text(0, 0.5, 't')

# %% [markdown]
# Now we sample on a square grid:

# %%
# Making training set
x_sample = np.linspace(-7, 5, 50)
t_sample = np.linspace(0.0, 1.0, 40)
x_grid_sample, t_grid_sample = np.meshgrid(x_sample, t_sample, indexing='ij')
X_train, y_train = dataset.create_dataset(x_grid_sample.reshape(-1, 1), t_grid_sample.reshape(-1, 1), n_samples=0, noise=0.1, normalize=True, random=True)

# %%
(0.1 * torch.std(y_train))**2
# Out:
# tensor(0.0041)

# %% [markdown]
# # Baseline NN

# %%
# Configuring model
network = NN(2, [30, 30, 30, 30, 30], 1)  # Function approximator
library = Library1D(poly_order=2, diff_order=3) # Library function
estimator = Threshold(0.1) #Clustering() # Sparse estimator 
constraint = LeastSquares() # How to constrain
model = DeepMoD(network, library, estimator, constraint) # Putting it all in the model

# Running model
sparsity_scheduler = Periodic(initial_epoch=2000, periodicity=100) # Defining when to apply sparsity
optimizer = torch.optim.Adam(model.parameters(), betas=(0.99, 0.99), amsgrad=True) # Defining optimizer

# %%
train(model, X_train, y_train, optimizer, sparsity_scheduler, delta=0.01, log_dir='runs/NN_baseline/') # Running
# Out:
# | Iteration | Progress | Time remaining |     Loss |      MSE |      Reg |    L1 norm |
#        2000     20.00%             335s   -7.28e+00   4.16e-03   3.15e-05   3.29e+00[tensor([False, False, False,  True, False,  True, False, False, False, False,
#         False, False])]
#        2100     21.00%             331s   -7.26e+00   4.19e-03   6.98e-05   2.60e+00[tensor([False, False, False,  True, False,  True, False, False, False, False,
#         False, False])]
#        2150     21.50%             330s   -7.26e+00   4.19e-03   6.48e-05   2.59e+00Algorithm converged. Stopping training.

# %%
model.estimator_coeffs()
# Out:
# [array([[ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.86879988],
#         [ 0.        ],
#         [-1.69161665],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ]])]

# %%
model.constraint_coeffs(sparse=True, scaled=True)
# Out:
# [tensor([[ 0.0000],
#          [ 0.0000],
#          [ 0.0000],
#          [-0.8813],
#          [ 0.0000],
#          [-1.7113],
#          [ 0.0000],
#          [ 0.0000],
#          [ 0.0000],
#          [ 0.0000],
#          [ 0.0000],
#          [ 0.0000]], grad_fn=<MaskedScatterBackward>)]

# %% [markdown]
# So it did that in a single run basically. Now let's check out SIREN.

# %% [markdown]
# # SIREN

# %%
# Configuring model
network = Siren(2, [30, 30, 30, 30, 30], 1)  # Function approximator
library = Library1D(poly_order=2, diff_order=3) # Library function
estimator = Threshold(0.1) #Clustering() # Sparse estimator 
constraint = LeastSquares() # How to constrain
model = DeepMoD(network, library, estimator, constraint) # Putting it all in the model

# Running model
sparsity_scheduler = Periodic(initial_epoch=500, periodicity=25) # Defining when to apply sparsity
optimizer = torch.optim.Adam(model.parameters(), betas=(0.999, 0.999), lr=0.00025, amsgrad=True) # Defining optimizer

# %%
train(model, X_train, y_train, optimizer, sparsity_scheduler, log_dir='runs/SIREN_baseline/', max_iterations=3000) # Running
# Out:
# | Iteration | Progress | Time remaining |     Loss |      MSE |      Reg |    L1 norm |
#         500     16.67%             103s   -4.66e+00   1.22e-02   5.73e-03   1.06e+01[tensor([False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])]
#         525     17.50%             102s   -4.70e+00   1.24e-02   4.98e-03   1.04e+01[tensor([False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])]
#         550     18.33%             102s   -4.84e+00   1.14e-02   4.94e-03   1.04e+01[tensor([False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True, False])]
#         575     19.17%             101s   -4.89e+00   1.08e-02   5.23e-03   9.32e+00[tensor([False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True, False])]
#         600     20.00%             101s   -5.06e+00   9.92e-03   4.89e-03   8.72e+00[tensor([False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True, False])]
#         625     20.83%             100s   -5.29e+00   8.69e-03   4.58e-03   7.85e+00[tensor([False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True, False])]
#         650     21.67%             100s   -5.53e+00   7.41e-03   4.49e-03   6.52e+00[tensor([False,  True,  True,  True, False,  True,  True,  True, False, False,
#          True, False])]
#         675     22.50%              99s   -5.67e+00   6.90e-03   4.18e-03   4.63e+00[tensor([False,  True,  True,  True, False,  True,  True,  True, False, False,
#          True, False])]
#         700     23.33%              98s   -5.90e+00   6.12e-03   3.80e-03   4.52e+00[tensor([False,  True, False,  True, False,  True,  True,  True, False, False,
#          True, False])]
#         725     24.17%              97s   -5.88e+00   5.72e-03   4.43e-03   3.01e+00[tensor([False,  True, False,  True, False,  True, False,  True, False, False,
#         False, False])]
#         750     25.00%              96s   -5.66e+00   6.17e-03   5.16e-03   2.45e+00[tensor([False,  True, False,  True, False,  True, False,  True, False, False,
#         False, False])]
#         775     25.83%              95s   -5.94e+00   5.28e-03   4.63e-03   2.45e+00[tensor([False,  True, False,  True, False,  True, False,  True, False, False,
#         False, False])]
#         800     26.67%              94s   -6.21e+00   4.91e-03   3.68e-03   2.44e+00[tensor([False,  True, False,  True, False,  True, False,  True, False, False,
#         False, False])]
#         825     27.50%              93s   -6.38e+00   4.69e-03   3.15e-03   2.53e+00[tensor([False,  True, False,  True, False,  True, False,  True, False, False,
#         False, False])]
#         850     28.33%              92s   -6.42e+00   4.43e-03   3.28e-03   2.48e+00[tensor([False, False, False,  True, False,  True, False, False, False, False,
#         False, False])]
#         875     29.17%              91s   -6.52e+00   4.37e-03   2.95e-03   2.56e+00[tensor([False, False, False,  True, False,  True, False, False, False, False,
#         False, False])]
#         900     30.00%              90s   -6.57e+00   4.35e-03   2.73e-03   2.58e+00[tensor([False, False, False,  True, False,  True, False, False, False, False,
#         False, False])]
#         925     30.83%              89s   -6.59e+00   4.35e-03   2.65e-03   2.54e+00[tensor([False, False, False,  True, False,  True, False, False, False, False,
#         False, False])]
#         950     31.67%              88s   -6.74e+00   4.28e-03   2.13e-03   2.55e+00[tensor([False, False, False,  True, False,  True, False, False, False, False,
#         False, False])]
# Algorithm converged. Stopping training.

# %%
model.estimator_coeffs()
# Out:
# [array([[ 0.        ],
#         [ 0.17168353],
#         [ 0.        ],
#         [-0.76225889],
#         [ 0.        ],
#         [-0.22567462],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ]])]

# %%
model.constraint_coeffs(sparse=True, scaled=False)
# Out:
# [tensor([[ 0.0000e+00],
#          [ 1.7143e-01],
#          [ 0.0000e+00],
#          [-4.5420e-06],
#          [ 0.0000e+00],
#          [-3.3190e-01],
#          [ 0.0000e+00],
#          [ 0.0000e+00],
#          [ 0.0000e+00],
#          [ 0.0000e+00],
#          [ 0.0000e+00],
#          [ 0.0000e+00]], grad_fn=<MaskedScatterBackward>)]

# %%
model.constraint_coeffs(scaled=True, sparse=True)
# Out:
# [tensor([[ 0.0000],
#          [ 0.0000],
#          [ 0.0000],
#          [-0.8803],
#          [ 0.0000],
#          [-1.7092],
#          [ 0.0000],
#          [ 0.0000],
#          [ 0.0000],
#          [ 0.0000],
#          [ 0.0000],
#          [ 0.0000]], grad_fn=<MaskedScatterBackward>)]

# %%
model.sparsity_masks
# Out:
# [tensor([False, False, False,  True, False,  True, False, False, False, False,
#          False, False])]

# %% [markdown]
# # Conclusion

# %% [markdown]
# We have a good set of parameters for which we now both work and when. let's now test the sensitivity of Siren w.r.t the first sparsity moment and check the MSE if we dont do sparsity.
